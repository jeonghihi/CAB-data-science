# %% [markdown]
# ### Importing relevant libraries and mounting Drive.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive

# %%
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %% [markdown]
# ### Importing the dataset.

# %%
#Created a dataframe for each product category that was joined to a final dataframe called "products". 

categories= ['headphones', 'keyboard', 'monitor', 'dslr_camera', 'laptop', 'mouse', 'processor','smartphone']

paths= ['/content/drive/MyDrive/CODEAcademy, DataScience- PINK EICHHOERNCHEN/e-commerce/search_output/Product_Summary_csv_files/Headphones_summary.csv', 
        '/content/drive/MyDrive/CODEAcademy, DataScience- PINK EICHHOERNCHEN/e-commerce/search_output/Product_Summary_csv_files/Keyboard_summary.csv', 
        '/content/drive/MyDrive/CODEAcademy, DataScience- PINK EICHHOERNCHEN/e-commerce/search_output/Product_Summary_csv_files/Monitor_summary.csv', 
        '/content/drive/MyDrive/CODEAcademy, DataScience- PINK EICHHOERNCHEN/e-commerce/search_output/Product_Summary_csv_files/dslr_camera_summary.csv',
        '/content/drive/MyDrive/CODEAcademy, DataScience- PINK EICHHOERNCHEN/e-commerce/search_output/Product_Summary_csv_files/laptop_summary.csv',
        '/content/drive/MyDrive/CODEAcademy, DataScience- PINK EICHHOERNCHEN/e-commerce/search_output/Product_Summary_csv_files/mouse_summary.csv',
        '/content/drive/MyDrive/CODEAcademy, DataScience- PINK EICHHOERNCHEN/e-commerce/search_output/Product_Summary_csv_files/Processor_summary.csv',
        '/content/drive/MyDrive/CODEAcademy, DataScience- PINK EICHHOERNCHEN/e-commerce/search_output/Product_Summary_csv_files/smartphones_summary(updated).csv'] 

empty= []

products= pd.DataFrame(empty)

for i in range(0,len(paths)):
  df= pd.read_csv(paths[i])
  products= products.append(df, ignore_index=True)

products.head(20)
# Out:
#                                                 title  ... Unnamed: 0
# 0   COWIN E7 Active Noise Cancelling Headphones Bl...  ...        NaN
# 1   COWIN E7 PRO [Upgraded] Active Noise Cancellin...  ...        NaN
# 2   Sony ZX Series Wired On-Ear Headphones, Black ...  ...        NaN
# 3   TOZO T6 True Wireless Earbuds Bluetooth Headph...  ...        NaN
# 4   Beats Solo3 Wireless On-Ear Headphones - Apple...  ...        NaN
# 5   PeohZarr On-Ear Headphones with Microphone, Li...  ...        NaN
# 6   Kurdene Wireless Earbuds,Bluetooth Earbuds wit...  ...        NaN
# 7   COWIN E7 Active Noise Cancelling Headphones Bl...  ...        NaN
# 8   LETSCOM Bluetooth Headphones V5.0 IPX7 Waterpr...  ...        NaN
# 9   Anker Soundcore Life Q20 Hybrid Active Noise C...  ...        NaN
# 10  VEATOOL Wireless Earbuds Bluetooth Headphones ...  ...        NaN
# 11  Heavy bass Earphone Color Call with Mic Stereo...  ...        NaN
# 12  Bluetooth Headphones Over-Ear, Zihnic Foldable...  ...        NaN
# 13  Kids Headphones, Mpow CHE2 Wired Headphones fo...  ...        NaN
# 14  Soundcore by Anker Life Q30 Hybrid Active Nois...  ...        NaN
# 15  LETSCOM Bluetooth Headphones, 100 Hours Playti...  ...        NaN
# 16  Earbuds - Earphone - Wired Headphones, 3.5mm i...  ...        NaN
# 17  TOZO T10 Bluetooth 5.0 Wireless Earbuds with W...  ...        NaN
# 18  Sony MDR7506 Professional Large Diaphragm Head...  ...        NaN
# 19  Audio-Technica ATH-M20X Professional Studio Mo...  ...        NaN
#
# [20 rows x 11 columns]

# %%
products.shape
# Out:
# (49238, 11)

# %% [markdown]
# ### Cleaning process.

# %%
#Checking how many missing values were in the dataframe. 

products.isnull().sum()
# Out:
# title               0
# url             14936
# rating           1514
# review_count     1514
# price            1948
# asin            34316
# prod_type       34316
# ASIN            14922
# product_type    14922
# sponsored       26814
# Unnamed: 0      41750
# dtype: int64

# %%
#Merging "ASIN" and "product_type" columns together with their duplicate.

products['ASIN']= products['ASIN'].fillna(products['asin'])
products['product_type']= products['product_type'].fillna(products['prod_type'])

# %%
#Confirming that the new "ASIN" and "product_type" columns have no missing values. 
products.isnull().sum()
# Out:
# title               0
# url             14936
# rating           1514
# review_count     1514
# price            1948
# asin            34316
# prod_type       34316
# ASIN                0
# product_type        0
# sponsored       26814
# Unnamed: 0      41750
# dtype: int64

# %%
#Dropped unnecessary or duplicated columns

products.drop(columns=['asin', 'prod_type', 'Unnamed: 0'], inplace= True)
products.head()
# Out:
#                                                title  ... sponsored
# 0  COWIN E7 Active Noise Cancelling Headphones Bl...  ...       NaN
# 1  COWIN E7 PRO [Upgraded] Active Noise Cancellin...  ...       NaN
# 2  Sony ZX Series Wired On-Ear Headphones, Black ...  ...       NaN
# 3  TOZO T6 True Wireless Earbuds Bluetooth Headph...  ...       NaN
# 4  Beats Solo3 Wireless On-Ear Headphones - Apple...  ...       NaN
#
# [5 rows x 8 columns]

# %%
#Reformatted 'product_type' column
products['product_type']= products['product_type'].replace('dslr camera', 'dslr_camera').apply(lambda x: x.lower())

#Reformatted 'rating' column 
products['rating'] = products['rating'].replace(['None','Non'],np.NaN)

#Reformatted 'review_count' column 
products['review_count'] = products['review_count'].replace(['None','Non'],0)
products.review_count.fillna(0, inplace=True)

#Reformatted 'price' column
products['price'] = products['price'].astype('str').apply(lambda x: x.replace('$', '').replace(',','') if '$' or ',' in x else x) 
products['price'] = products['price'].replace(['None','Non'],np.NaN)

# %%
#Converted column types
products= products.astype({'rating': 'float', 'review_count': 'int', 'price': 'float'})

# %%
products.shape
# Out:
# (49238, 8)

# %%
#Created a 'duplicated' dataframe with the rows whose value in the 'ASIN' column were duplicated
duplicated= products[products['ASIN'].duplicated(keep= 'last')][['ASIN']]
duplicated['sponsored']= 1

#Removed duplicated values from the 'ASIN' column. Decided to keep last occurence. 
print('Number of rows before removing duplicated ASIN:', products.shape[0])
products.drop_duplicates(subset= 'ASIN', keep='last', inplace= True)
print('Number of rows after removing duplicated ASIN:', products.shape[0])
print('\n')

#Joined the products dataframe together with the duplicated dataframe. 
products= products.join(duplicated.set_index('ASIN'), on='ASIN', rsuffix='_duplicated')

#Replaced missing values in the 'sponsored' column of the products dataframe with the one from the 'duplicated' dataframe, and the remaining missing values with zero (0)
products['sponsored']= products['sponsored'].fillna(products['sponsored_duplicated'])
products['sponsored']= products['sponsored'].fillna(0)

#Dropped irrelevant column
products= products.drop(columns= ['sponsored_duplicated'])

print(products.isnull().sum())
# Out:
# Number of rows before removing duplicated ASIN: 49238
# Number of rows after removing duplicated ASIN: 34516
#
#
# title               0
# url             14757
# rating           3881
# review_count        0
# price            4704
# ASIN                0
# product_type        0
# sponsored           0
# dtype: int64

# %%
#Top 10 products sorting by rating and then review count

for i in categories: 
  print(i.upper())
  print('Amount of products that have a 5.0 rating:', products[(products['product_type']==i) & (products['rating']==5.0)].loc[:,].shape[0])
  print('\n')
  print('Top 10 products based on rating and review_count:')
  df= products[products['product_type']==i].sort_values(by=['rating', 'review_count'], ascending= False).head(10).loc[:,['title', 'rating', 'review_count']]
  df.index = range(1, 11)
  print(df)
  name = '/content/drive/MyDrive/CODE Data Science/Project3-E-Commerce/Top-10-Products/Top-ten-products_by_rating_' + i + '.csv'
  df.to_csv(name)
  print('\n')
# Out:
# HEADPHONES
# Amount of products that have a 5.0 rating: 238
#
#
# Top 10 products based on rating and review_count:
#                                                 title  rating  review_count
# 1   MOVONE True Wireless Earbuds Sport Bluetooth H...     5.0           150
# 2   Aux Cord for iPhone,3.5mm Aux Cable Compatible...     5.0           113
# 3   SUPSOO Stereo Gaming Headphones for PS4, PC, X...     5.0            39
# 4   Lecover Wireless Earbuds, Bluetooth 5.0 Headph...     5.0            26
# 5   Headphone Adapter for iPhone, [Apple MFi Certi...     5.0            24
# 6   15ft 3.5mm Aux Audio Cable,Faodzc 90°Angled 3....     5.0            21
# 7   Minelab ML 80 Bluetooth Wireless / Wired Low L...     5.0            20
# 8   True Wireless Stereo HiFi Earbuds VOTOMY TWS E...     5.0            18
# 9   NIMASO 2 in 1 USB C to 3.5mm Microphone Headph...     5.0            16
# 10  SoundPEATS Sonic Wireless Earbuds V5.2 Bluetoo...     5.0            16
#
#
# KEYBOARD
# Amount of products that have a 5.0 rating: 630
#
#
# Top 10 products based on rating and review_count:
#                                                 title  rating  review_count
# 1   Android Tablet 10 inch, HD Touchscreen 2-in-1 ...     5.0            17
# 2   Vissles-V1 Wireless Bluetooth/USB Wired Mechan...     5.0            17
# 3   ALPTHY Air Duster, Electric Cordless Air Duste...     5.0            17
# 4   Baby Yoda Mouse Pad with Stitched Edge Non-Sli...     5.0            14
# 5   CaseBuy Keyboard Cover for Lenovo 510 Wireless...     5.0            13
# 6   Cherry KC 1000, Smartcard TAA Compliant USB Ke...     5.0            13
# 7   RUYIDAY Keyboard Wrist Rest Set and Ergonomic ...     5.0            11
# 8   INFILAND Compatible with iPad Air 4 Keyboard C...     5.0            10
# 9   Razer Ornata V2 Gaming Keyboard- Detachable Pl...     5.0            10
# 10  MOSISO Pattern Keyboard Cover Compatible with ...     5.0            10
#
#
# MONITOR
# Amount of products that have a 5.0 rating: 655
#
#
# Top 10 products based on rating and review_count:
#                                                 title  rating  review_count
# 1   Portable Monitor, BOIFUN 15.8" Type-C 1080P Co...     5.0            41
# 2   Replacement Capacitors, Compatible with Westin...     5.0            27
# 3   STOON Monitor Stand, Computer Monitor Stand Ri...     5.0            23
# 4   USB to HDMI Adapter HD 1080P Video Graphics Ca...     5.0            22
# 5   Dell P3221D 32 Inch 1440p QHD, IPS Ultra-Thin ...     5.0            19
# 6   EVanlak DVI Dummy Plug Headless Ghost Function...     5.0            19
# 7    LG 27" 27MN60T-W Class FHD IPS Monitor (Renewed)     5.0            16
# 8   Computer Monitor Light, Gulito Screen Light Ba...     5.0            16
# 9   UpBright 6V AC/DC Adapter Compatible with Sams...     5.0            16
# 10  StepUp Premium 2in1 Laptop Stand,Phone Holder ...     5.0            13
#
#
# DSLR_CAMERA
# Amount of products that have a 5.0 rating: 591
#
#
# Top 10 products based on rating and review_count:
#                                                 title  rating  review_count
# 1   Nitze Stinger Handle Top Handle Grip for Camer...     5.0            44
# 2   Canon EOS-1D X Mark III DSLR Camera | with CFe...     5.0            25
# 3   Canon EOS 70D (8469B002) Digital SLR Cameras B...     5.0            25
# 4   EnYL's Vintage Camera Strap，Compatible with Un...     5.0            21
# 5       Ruggard Thunderhead 75 DSLR & Laptop Backpack     5.0            19
# 6   Nikon BL-1, Replacement Battery Chamber Cover ...     5.0            17
# 7   Hahnel PROCUBE2 Professional Twin Battery Char...     5.0            16
# 8   55 Inch Camera Tripod, ViWAA Aluminum Lightwei...     5.0            16
# 9   Pentax K-1 Mark II w/ D-FA 28-105 WR Lens: 36....     5.0            14
# 10  Glide Gear OH 150 Overhead Camera Light Platfo...     5.0            13
#
#
# LAPTOP
# Amount of products that have a 5.0 rating: 327
#
#
# Top 10 products based on rating and review_count:
#                                                 title  rating  review_count
# 1   2021 Newest HP 15 Budget Laptop Notebook, 15.6...     5.0            13
# 2   HP 17-by3065st 17.3" Notebook 10th GEN i5 8GB ...     5.0            12
# 3   2019 HP Envy x360 15.6" FHD Touchscreen 2-in-1...     5.0            12
# 4   15.6 inch Laptop (Intel J3455 64 bit ,8GB DDR3...     5.0            10
# 5   ASUS VivoBook 15 Thin and Light Laptop, 15.6” ...     5.0            10
# 6   HP - OMEN 15-EK0013DX 15.6" Gaming Laptop 10th...     5.0             9
# 7   HP Pavilion x360 Premium 2 in 1 Laptop Compute...     5.0             9
# 8   Dell Latitude 3510 15.6" FHD Business Laptop C...     5.0             8
# 9   Dell Latitude E5550 15.6in Laptop, Core i5-520...     5.0             8
# 10  Acer Chromebox CXI3 Intel i3-7130U 2.70GHz 8GB...     5.0             8
#
#
# MOUSE
# Amount of products that have a 5.0 rating: 644
#
#
# Top 10 products based on rating and review_count:
#                                                 title  rating  review_count
# 1   PeohZarr Gaming Mouse, Blue Purple Gradient Co...     5.0            88
# 2   Demon Slayer Inosuke Hashibira Anime Mouse Pad...     5.0            68
# 3   Bounce Generation—Wireless Vertical Mouse, 5th...     5.0            49
# 4   Baby Yo-da Universal Fashion and Environmental...     5.0            47
# 5   Smooffly Gaming Mouse Pad Custom,Inspirational...     5.0            45
# 6   Smooffly African Gaming Mouse Pad Custom,Four ...     5.0            40
# 7   Demon Slayer Tanjiro Kamado Anime Mouse Pad La...     5.0            38
# 8   Smooffly Gaming Mouse Pad Custom,Full Moon wit...     5.0            37
# 9   Ergonomic Mouse Pad with Gel Wrist Rest Suppor...     5.0            33
# 10  Cute Cat Stand on a Hamburger in Galaxy Space ...     5.0            32
#
#
# PROCESSOR
# Amount of products that have a 5.0 rating: 33
#
#
# Top 10 products based on rating and review_count:
#                                                 title  rating  review_count
# 1   Samsung Electronics A7 Tablet 10.4 Wi-Fi 64 GB...     5.0            11
# 2   Feonal Tablet 10 inch Android 9.0 Tablet with ...     5.0             8
# 3                                 Intel Core i7-6700K     5.0             7
# 4   Intel Boxed Core i7-6800K Processor (15M Cache...     5.0             6
# 5   Intel Xeon Processor E5-2650 v2 BX80635E52650V...     5.0             5
# 6   Intel SSD D3-S4610 Series SSDSC2KG019T801 1.92...     5.0             4
# 7   Intel Core i5-3210M SR0MZ 2.5GHz 3MB Dual-core...     5.0             4
# 8   Intel Xeon E5-2650 v3 Ten-Core Haswell Process...     5.0             3
# 9   Acer Enduro T1 ET108-11A-80PZ Rugged Tablet, 8...     5.0             3
# 10  2QX8542 - Intel Core i5 i5-4670 3.40 GHz Proce...     5.0             3
#
#
# SMARTPHONE
# Amount of products that have a 5.0 rating: 539
#
#
# Top 10 products based on rating and review_count:
#                                                 title  rating  review_count
# 1   Godox X2T-C 2.4G TTL Wireless Flash Trigger wi...     5.0            38
# 2   Car Phone Holder, OMOTON Magnetic Car Phone Mo...     5.0            31
# 3   KSACLE Second Generation Car Phone Mount/Socke...     5.0            25
# 4   Magnetic Phone Car Mount 360° Rotation Metal (...     5.0            21
# 5   Lenovo 45W USB-C Ultraportable Adapter, AC Wal...     5.0            21
# 6   Procase Hard EVA Carrying Case for Canon Ivy M...     5.0            18
# 7   BT21 Official Newest Merchandise, Phone Card P...     5.0            17
# 8   Face, Body & Action Auto Tracking Phone Holder...     5.0            16
# 9   Phone Ring Holder Finger Kickstand, CISID 360°...     5.0            16
# 10  Stylus for iPad, LezGo StylusPen for Touch Scr...     5.0            13

# %%
#Top 10 products sorting by review count and then rating

for i in categories: 
  print(i.upper())
  print('\n')
  print('Top 10 products based on review_count:')
  df= products[products['product_type']==i].sort_values(by=['review_count', 'rating'], ascending= False).head(10).loc[:,['title', 'rating', 'review_count']]
  df.index = range(1, 11)
  print(df)
  name = '/content/drive/MyDrive/CODE Data Science/Project3-E-Commerce/Top-10-Products/Top-ten-products_by_review_count_' + i + '.csv'
  df.to_csv(name)
  print('\n')
# Out:
# HEADPHONES
#
#
# Top 10 products based on review_count:
#                                                 title  rating  review_count
# 1            Apple AirPods with Charging Case (Wired)     4.8        365231
# 2   TOZO T10 Bluetooth 5.0 Wireless Earbuds with W...     4.4        198041
# 3                                   Apple AirPods Pro     4.8        176569
# 4     Apple EarPods with 3.5mm Headphone Plug - White     4.7        119660
# 5    Apple Lightning to 3.5 mm Headphone Jack Adapter     4.7        113968
# 6   Panasonic ErgoFit In-Ear Earbud Headphones RP-...     4.3        111936
# 7   TOZO T6 True Wireless Earbuds Bluetooth Headph...     4.5        106219
# 8   COWIN E7 Active Noise Cancelling Headphones Bl...     4.4         69726
# 9   COWIN E7 Active Noise Cancelling Headphones Bl...     4.4         69726
# 10  Anker Soundcore Life P2 True Wireless Earbuds ...     4.3         69653
#
#
# KEYBOARD
#
#
# Top 10 products based on review_count:
#                                                 title  rating  review_count
# 1   MOSISO Compatible with MacBook Air 13 inch Cas...     4.3         31343
# 2   MOSISO Laptop Sleeve Bag Compatible with MacBo...     4.7         30760
# 3   Cleaning Gel Universal Dust Cleaner for PC Key...     4.2         28549
# 4   Acer Aspire 5 A515-44-R41B, 15.6" Full HD, AMD...     4.6         26914
# 5   Amazon Basics Gaming Keyboard and Mouse Pad Bu...     4.6         26147
# 6   Razer Kraken Gaming Headset: Lightweight Alumi...     4.6         26081
# 7   MOSISO MacBook Air 13 inch Case 2020 2019 2018...     4.3         24846
# 8   Leather Desk Pad Protector,Mouse Pad,Office De...     4.7         22670
# 9   Redragon K552 Mechanical Gaming Keyboard RGB L...     4.4         22280
# 10  Soundance Laptop Stand, Aluminum Computer Rise...     4.8         21848
#
#
# MONITOR
#
#
# Top 10 products based on review_count:
#                                                 title  rating  review_count
# 1            Fire 7 tablet (7" display, 16 GB) - Sage     4.4        175133
# 2   Corsair Vengeance LPX 16GB (2x8GB) DDR4 DRAM 3...     4.8         79137
# 3   Samsung SSD 860 EVO 1TB 2.5 Inch SATA III Inte...     4.9         63378
# 4   TIJN Blue Light Blocking Glasses for Women Men...     4.4         56125
# 5   Seagate BarraCuda 2TB Internal Hard Drive HDD ...     4.7         55296
# 6   Amazon Basics HDMI to DVI Adapter Cable, Black...     4.7         49962
# 7   Creative Pebble 2.0 USB-Powered Desktop Speake...     4.6         43961
# 8   QGeeM USB C to HDMI Adapter 4K Cable, USB Type...     4.5         41445
# 9   Acer SB220Q bi 21.5 Inches Full HD (1920 x 108...     4.7         40358
# 10  Western Digital 1TB WD Blue 3D NAND Internal P...     4.8         39125
#
#
# DSLR_CAMERA
#
#
# Top 10 products based on review_count:
#                                                 title  rating  review_count
# 1   SanDisk 128GB Extreme PRO SDXC UHS-I Card - C1...     4.8         91337
# 2   SanDisk Ultra 128GB SDXC UHS-I Memory Card up ...     4.7         75631
# 3   SanDisk 128GB Ultra SDXC UHS-I Memory Card - 1...     4.7         55328
# 4   Amazon Basics 60-Inch Lightweight Tripod with Bag     4.6         54627
# 5   Amazon Basics Lightweight Camera Mount Tripod ...     4.5         48545
# 6   Neewer Ring Light Kit:18"/48cm Outer 55W 5500K...     4.7         38174
# 7   Phone Tripod, UBeesize Portable and Adjustable...     4.5         37951
# 8   SanDisk 128GB Extreme SDXC UHS-I Card - C10, U...     4.8         33795
# 9   Samsung BAR Plus USB 3.1 Flash Drive 128GB - 4...     4.7         29178
# 10  Anker 2-in-1 USB 3.0 SD Card Reader for SDXC, ...     4.7         24368
#
#
# LAPTOP
#
#
# Top 10 products based on review_count:
#                                                 title  rating  review_count
# 1   Acer Aspire 5 Slim Laptop, 15.6 inches Full HD...     4.6         26914
# 2   Apple MacBook Air (13-inch Retina Display, 8GB...     4.8          9939
# 3   Lenovo Chromebook C330 2-in-1 Convertible Lapt...     4.5          6790
# 4   ASUS Laptop L210 Ultra Thin Laptop, 11.6” HD D...     4.3          6660
# 5   Acer Chromebook Spin 311 Convertible Laptop, I...     4.6          5143
# 6   1080P Webcam with Microphone, C960 Web Camera,...     4.4          5138
# 7   1080P Webcam with Microphone, C960 Web Camera,...     4.4          5138
# 8   1080P Webcam with Microphone, C960 Web Camera,...     4.4          5138
# 9   1080P Webcam with Microphone, C960 Web Camera,...     4.4          5138
# 10  1080P Webcam with Microphone, C960 Web Camera,...     4.4          5138
#
#
# MOUSE
#
#
# Top 10 products based on review_count:
#                                                 title  rating  review_count
# 1   seenda Wireless Mouse, 2.4G Noiseless Mouse wi...     4.6         66818
# 2   SteelSeries QcK Mini Gaming Mouse Pad Black, S...     4.7         52421
# 3   VicTsing Mouse Pad with Stitched Edge, Premium...     4.6         46061
# 4   Logitech MK270 Wireless Keyboard and Mouse Com...     4.6         41367
# 5   Logitech M570 Wireless Trackball Mouse – Ergon...     4.6         40155
# 6   Anker 2.4G Wireless Vertical Ergonomic Optical...     4.3         31474
# 7   Acer Aspire 5 Slim Laptop A515-43-R19L 15.6" F...     4.6         27105
# 8   Logitech G502 Hero High Performance Wired Gami...     4.7         26917
# 9     Amazon Basics Gaming Computer Mouse Pad - Black     4.6         26364
# 10  Corsair MM300 - Anti-Fray Cloth Gaming Mouse P...     4.8         25699
#
#
# PROCESSOR
#
#
# Top 10 products based on review_count:
#                                                 title  rating  review_count
# 1   Fire HD 10 Tablet (64 GB, Plum, Ad-Supported) ...     4.6        179007
# 2   AMD Ryzen 5 3600 6-Core, 12-Thread Unlocked De...     4.9         30844
# 3   AMD Ryzen 7 3700X 8-Core, 16-Thread Unlocked D...     4.9         19295
# 4   Noctua NT-H1 3.5g, Pro-Grade Thermal Compound ...     4.8         12820
# 5   Intel Core i7-9700K Desktop Processor 8 Cores ...     4.8          7691
# 6   Western Digital 8TB WD Black Performance Inter...     4.6          7253
# 7   AMD Ryzen 3 3200G 4-Core Unlocked Desktop Proc...     4.7          6800
# 8   AMD Ryzen 5 1600 65W AM4 Processor with Wraith...     4.8          5741
# 9   AMD Ryzen 5 3400G 4-core, 8-Thread Unlocked De...     4.8          5038
# 10  Linksys (WHW0303) Velop Mesh Router (Tri-Band ...     4.2          5027
#
#
# SMARTPHONE
#
#
# Top 10 products based on review_count:
#                                                 title  rating  review_count
# 1   Samsung Electronics EVO Select 256GB MicroSDXC...     4.8        135303
# 2   SanDisk 128GB microSDXC-Card, Licensed for Nin...     4.9        118276
# 3   Cell Phone Stand, Lamicall Phone Cradle : Phon...     4.7         63795
# 4   Syncwire Long Aux Cable 6.5Ft- Auxiliary Audio...     4.6         63322
# 5   Sony ZX Series Wired On-Ear Headphones with Mi...     4.5         50333
# 6   Phone Ring Holder Finger Kickstand - FITFORT 3...     4.5         46359
# 7   iOttie Easy One Touch 4 Dash & Windshield Car ...     4.5         44709
# 8   SanDisk 400GB Ultra microSDXC UHS-I Memory Car...     4.8         43541
# 9   Power Strip, bototek Surge Protector with 10 A...     4.8         35335
# 10  BONAOK Bluetooth Wireless Karaoke Microphone,3...     4.5         34812

# %%
products.groupby(['product_type', 'sponsored'])[['rating','review_count', 'price']].mean()
# Out:
#                           rating  review_count       price
# product_type sponsored
# dslr_camera  0.0        4.368953    349.160079  161.675336
#              1.0        4.483295    383.522843  328.507070
# headphones   0.0        4.243108   1564.939234   41.872064
#              1.0        4.142203   1330.814256   75.583785
# keyboard     0.0        4.324055    462.082109   37.022220
#              1.0        4.533768    400.446545   28.429100
# laptop       0.0        4.166059    146.233498  969.361581
#              1.0        4.170141    215.955243  413.521439
# monitor      0.0        4.315446    672.180520  132.351745
#              1.0        4.503704    276.421908   59.728304
# mouse        0.0        4.553578    773.347420   20.162534
#              1.0        4.454748    178.061568   42.903838
# processor    0.0        4.427536   2145.065217  369.269493
#              1.0        4.161083    154.285816  319.010107
# smartphone   0.0        4.167474    646.953624   60.011994
#              1.0        4.405376    638.425269  201.597481

# %%
products[products['product_type']=='mouse'].loc[:,['price', 'rating', 'review_count', 'sponsored']].corr()
# Out:
#                  price    rating  review_count  sponsored
# price         1.000000 -0.253118      0.049004   0.199429
# rating       -0.253118  1.000000     -0.002216  -0.131375
# review_count  0.049004 -0.002216      1.000000  -0.106465
# sponsored     0.199429 -0.131375     -0.106465   1.000000
